# %%
import os
os.chdir("../")
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt

# %%
dataset = rasterio.open(os.getcwd() + "/data/forest_loss_porijogi_wgs84.tif")
print(f"shape: {dataset.shape}, count: {dataset.count}")
# Out:
# shape: (687, 1326), count: 1

# %%
src = dataset.read(1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
ax1.imshow(src, cmap='pink');
show(src, ax=ax2);
